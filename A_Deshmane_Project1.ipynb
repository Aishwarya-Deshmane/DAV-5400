# %% [markdown]
# # Project 1 : Exploratory Data Analysis Using Matplotlib & Seaborn

# %% [markdown]
# ### Submitted by :
#
# Sweety Saha (ssaha2@mail.yu.edu)
#
# Aishwarya Deshmane (adeshman@mail.yu.edu)
#
# Nabid Zaman (nzaman@mail.yu.edu)

# %%
# Load Pandas library as pd, pyplot from matplotlib as plt and seaborn as sns

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
unemp = 'https://github.com/Aishwarya-Deshmane/DAV-5400/raw/main/Unemployment_US.csv'
df = pd.read_csv(unemp) # Dataset is now stored in the pandas dataframe

# %% [markdown]
# It's crucial to comprehend the data, different properties, and dataset structure before we begin working on the project. We would then be in a lot better position to do analysis properly. By reading the dataset's description and details, as well as by looking at the dataset's head and tail, we'll aim to do this.

# %%
#Checking the head of the dataset:
df.head()
# Out:
#    FIPS_code State           Area_name  Civilian_labor_force_2017  \
# 0       1001    AL  Autauga County, AL                    26269.0
# 1       1003    AL  Baldwin County, AL                    93152.0
# 2       1005    AL  Barbour County, AL                     8415.0
# 3       1007    AL     Bibb County, AL                     8648.0
# 4       1009    AL   Blount County, AL                    25009.0
#
#    Employed_2017  Unemployed_2017  Unemployment_rate_2017  \
# 0        25224.0           1045.0                     4.0
# 1        89286.0           3866.0                     4.2
# 2         7914.0            501.0                     6.0
# 3         8261.0            387.0                     4.5
# 4        23979.0           1030.0                     4.1
#
#    Civilian_labor_force_2018  Employed_2018  Unemployed_2018  ...  \
# 0                    26475.0        25524.0            951.0  ...
# 1                    96252.0        92769.0           3483.0  ...
# ...

# %%
#Checking the tail of the dataset:
df.tail()
# Out:
#       FIPS_code State                Area_name  Civilian_labor_force_2017  \
# 3219      72145    PR  Vega Baja Municipio, PR                    13414.0
# 3220      72147    PR    Vieques Municipio, PR                     3027.0
# 3221      72149    PR   Villalba Municipio, PR                     7557.0
# 3222      72151    PR    Yabucoa Municipio, PR                     9000.0
# 3223      72153    PR      Yauco Municipio, PR                    10160.0
#
#       Employed_2017  Unemployed_2017  Unemployment_rate_2017  \
# 3219        11746.0           1668.0                    12.4
# 3220         2589.0            438.0                    14.5
# 3221         6090.0           1467.0                    19.4
# 3222         7512.0           1488.0                    16.5
# 3223         8409.0           1751.0                    17.2
#
#       Civilian_labor_force_2018  Employed_2018  Unemployed_2018  ...  \
# 3219                    13159.0        11787.0           1372.0  ...
# ...

# %% [markdown]
# So there are a total of 3224 rows and 33 columns. But we will again confirm the order by using the 'shape' method:

# %%
# Let's view the shape of our dataframe:
df.shape
# Out:
# (3224, 23)

# %% [markdown]
# Thus, it supported what we had already evaluated. Additionally, "FIPS_code, State, and County" are categorical attributes according to our preliminary research, whereas the other attributes are numeric ratio attributes.

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ### What type of data is chosen for the research and why this analysis?
#
# Through a federal-state partnership known as the Local Area Unemployment Statistics (LAUS) program, annual total estimates of the civilian labor force, employed individuals, unemployed people, and unemployment rates are generated for more than 3,000 distinct subnational regions. BLS uses models that include real-time benchmarking to the national total employment and unemployment levels from the Current Population Survey to provide state-wide estimates (CPS). The controls for substate-area estimation are these model-based estimations for the states. Under the supervision of BLS, state labor market information offices create data for substate regions utilizing standardized techniques, software systems, and certain inputs supplied by BLS.
#
#
# The US government intends to compare the employment and unemployment figures in each county and state before and after the implementation of Covid.
# The US government intends to highlight any county with a higher than 100,000 unemployment rate as well as the county with the highest unemployment rate ever. What proportion of counties have higher unemployment rates?

# %% [markdown]
# ### Research objective : Employment and Unemployment Performance of each State/County of United States
#
# The scenario we choose to answer our objective is where the USA government wishes to monitor the employment and unemployment rates for the past five years (2017–2021) that are being assessed by the LAUS. The government can examine the employment and unemployment rate figures in this performance evaluation and determine which State or which County needs attention. It has also been the helpful data to know the impact of Covid.

# %% [markdown]
# #### Below questions will help us understand to get the overview of the above objective:
#
# Find the County/State that has highest employment/unemployment rate per state.
#
# Find the percentage of 2021 Employment rate which are between 80 and 90.
#
# Find labor force trend year-wise for each state.
#
# What is the proportion of county with highest 3 employment rates?
#
# What is the proportion of county with lowest 3 employment rates?
#
# Which county has all time worst unemployment rate?
#
# Compare among NY, NJ & CT

# %% [markdown]
# ## 2. Data Summary:
# We go the data from 'Data.gov'. We found this data a good example of real world and to understand know what is happening around us

# %% [markdown]
# Our procedure begins by adding a few columns that we will need for our analysis. We already know that we are doing research over the period of 2017 to 2021. The "total labor", "total employed", "total unemployed", "emp rate", and "unemp rate" columns will be added.

# %%
# Calculating the "total labor", "total employed", "total unemployed", "emp rate", and "unemp rate".

df['total_labor']=df.iloc[:,[3,7,11,15,19]].sum(axis=1)

df['total_employed']=df.iloc[:,[4,8,12,16,20]].sum(axis=1)

df['total_unemployed']=df.iloc[:,[5,9,13,17,21]].sum(axis=1)

df['emp_rate']=(df['total_employed']/df['total_labor']) #employment rate

df['unemp_rate']=(df['total_unemployed']/df['total_labor']) #unemployment rate

df
# Out:
#       FIPS_code State                Area_name  Civilian_labor_force_2017  \
# 0          1001    AL       Autauga County, AL                    26269.0
# 1          1003    AL       Baldwin County, AL                    93152.0
# 2          1005    AL       Barbour County, AL                     8415.0
# 3          1007    AL          Bibb County, AL                     8648.0
# 4          1009    AL        Blount County, AL                    25009.0
# ...         ...   ...                      ...                        ...
# 3219      72145    PR  Vega Baja Municipio, PR                    13414.0
# 3220      72147    PR    Vieques Municipio, PR                     3027.0
# 3221      72149    PR   Villalba Municipio, PR                     7557.0
# 3222      72151    PR    Yabucoa Municipio, PR                     9000.0
# 3223      72153    PR      Yauco Municipio, PR                    10160.0
#
#       Employed_2017  Unemployed_2017  Unemployment_rate_2017  \
# ...

# %%
# Description of the dataset:

df.describe()
# Out:
#           FIPS_code  Civilian_labor_force_2017  Employed_2017  \
# count   3224.000000               3.219000e+03   3.219000e+03
# mean   31353.364144               5.027692e+04   4.806521e+04
# std    16320.003061               1.654931e+05   1.580790e+05
# min     1001.000000               1.000000e+02   9.500000e+01
# 25%    19026.500000               4.949500e+03   4.693500e+03
# 50%    30020.000000               1.135900e+04   1.083200e+04
# 75%    46103.500000               3.089550e+04   2.963900e+04
# max    72153.000000               5.109810e+06   4.864120e+06
#
#        Unemployed_2017  Unemployment_rate_2017  Civilian_labor_force_2018  \
# count      3219.000000             3219.000000               3.219000e+03
# mean       2211.709537                4.796893               5.067456e+04
# std        7551.349608                2.177360               1.666526e+05
# min           5.000000                1.500000               2.090000e+02
# ...

# %%
# Now, let's  check the detailed information of the dataset like datatype, Non-Null count etc:

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3224 entries, 0 to 3223
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   FIPS_code                  3224 non-null   int64
#  1   State                      3224 non-null   object
#  2   Area_name                  3224 non-null   object
#  3   Civilian_labor_force_2017  3219 non-null   float64
#  4   Employed_2017              3219 non-null   float64
#  5   Unemployed_2017            3219 non-null   float64
#  6   Unemployment_rate_2017     3219 non-null   float64
#  7   Civilian_labor_force_2018  3219 non-null   float64
#  8   Employed_2018              3219 non-null   float64
#  9   Unemployed_2018            3219 non-null   float64
#  10  Unemployment_rate_2018     3219 non-null   float64
#  11  Civilian_labor_force_2019  3219 non-null   float64
#  12  Employed_2019              3219 non-null   float64
# ...

# %% [markdown]
# We can see from the above result that there are no 'nulls' in our dataset since the total non-null values are 3224.

# %% [markdown]
# Now we have added the Employment_rate columns for each year to the Unemployment_data dataset (adding the columns so it can be used for further calculations when needed).To add multiple columns, use assign function.
# Calculate the employment rate values dividing Employed by the civilian_labor_force and multiply by 100 Print the subset of the data to check the output

# %%
df = df.assign(Employment_rate_2021 = round(df['Employed_2021']*100/df['Civilian_labor_force_2021'],1),
                                             Employment_rate_2017 = round(df['Employed_2017']*100/df['Civilian_labor_force_2017'],1),
                                             Employment_rate_2018 = round(df['Employed_2018']*100/df['Civilian_labor_force_2018'],1),
                                             Employment_rate_2019 = round(df['Employed_2019']*100/df['Civilian_labor_force_2019'],1),
                                             Employment_rate_2020 = round(df['Employed_2020']*100/df['Civilian_labor_force_2020'],1))
df.head()
# Out:
#    FIPS_code State           Area_name  Civilian_labor_force_2017  \
# 0       1001    AL  Autauga County, AL                    26269.0
# 1       1003    AL  Baldwin County, AL                    93152.0
# 2       1005    AL  Barbour County, AL                     8415.0
# 3       1007    AL     Bibb County, AL                     8648.0
# 4       1009    AL   Blount County, AL                    25009.0
#
#    Employed_2017  Unemployed_2017  Unemployment_rate_2017  \
# 0        25224.0           1045.0                     4.0
# 1        89286.0           3866.0                     4.2
# 2         7914.0            501.0                     6.0
# 3         8261.0            387.0                     4.5
# 4        23979.0           1030.0                     4.1
#
#    Civilian_labor_force_2018  Employed_2018  Unemployed_2018  ...  \
# 0                    26475.0        25524.0            951.0  ...
# 1                    96252.0        92769.0           3483.0  ...
# ...

# %%
#check Description of the new dataset:

df.describe()
# Out:
#           FIPS_code  Civilian_labor_force_2017  Employed_2017  \
# count   3224.000000               3.219000e+03   3.219000e+03
# mean   31353.364144               5.027692e+04   4.806521e+04
# std    16320.003061               1.654931e+05   1.580790e+05
# min     1001.000000               1.000000e+02   9.500000e+01
# 25%    19026.500000               4.949500e+03   4.693500e+03
# 50%    30020.000000               1.135900e+04   1.083200e+04
# 75%    46103.500000               3.089550e+04   2.963900e+04
# max    72153.000000               5.109810e+06   4.864120e+06
#
#        Unemployed_2017  Unemployment_rate_2017  Civilian_labor_force_2018  \
# count      3219.000000             3219.000000               3.219000e+03
# mean       2211.709537                4.796893               5.067456e+04
# std        7551.349608                2.177360               1.666526e+05
# min           5.000000                1.500000               2.090000e+02
# ...

# %% [markdown]
# ## 3. Exploratory Data Analysis:

# %%
# We will now determine the distinct values of our characteristics for our categorical data:

# unique values for 'state':
df.State.unique()
# Out:
# array(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA',
#        'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA',
#        'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY',
#        'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY', 'PR'], dtype=object)

# %%
# unique values for 'County':
df.Area_name.unique()
# Out:
# array(['Autauga County, AL', 'Baldwin County, AL', 'Barbour County, AL',
#        ..., 'Villalba Municipio, PR', 'Yabucoa Municipio, PR',
#        'Yauco Municipio, PR'], dtype=object)

# %%
# unique values for 'FIPS_code':
df.FIPS_code.unique()
# Out:
# array([ 1001,  1003,  1005, ..., 72149, 72151, 72153])

# %%
# verify the number of counties in the state of "MS."
df.Area_name[(df['State'] == 'MS')].unique()
# Out:
# array(['Adams County, MS', 'Alcorn County, MS', 'Amite County, MS',
#        'Attala County, MS', 'Benton County, MS', 'Bolivar County, MS',
#        'Calhoun County, MS', 'Carroll County, MS', 'Chickasaw County, MS',
#        'Choctaw County, MS', 'Claiborne County, MS', 'Clarke County, MS',
#        'Clay County, MS', 'Coahoma County, MS', 'Copiah County, MS',
#        'Covington County, MS', 'DeSoto County, MS', 'Forrest County, MS',
#        'Franklin County, MS', 'George County, MS', 'Greene County, MS',
#        'Grenada County, MS', 'Hancock County, MS', 'Harrison County, MS',
#        'Hinds County, MS', 'Holmes County, MS', 'Humphreys County, MS',
#        'Issaquena County, MS', 'Itawamba County, MS',
#        'Jackson County, MS', 'Jasper County, MS', 'Jefferson County, MS',
#        'Jefferson Davis County, MS', 'Jones County, MS',
#        'Kemper County, MS', 'Lafayette County, MS', 'Lamar County, MS',
# ...

# %% [markdown]
#  We now require information on the number of unemployed persons in each county with more than 100,000 unemployed in 2021. We construct a new dataframe called "pe" that contains only that information for 2021, when there will be over 100,000 jobless persons.

# %%
pe = df.Area_name[(df['Unemployed_2021'] >= 100000)].unique()
pe
# Out:
# array(['Maricopa County, AZ', 'Los Angeles County, CA', 'Cook County, IL',
#        'Kings County, NY', 'Queens County, NY', 'Harris County, TX'],
#       dtype=object)

# %% [markdown]
# Using correlation function to understand if any columns have direct or indirect correlation with any other column
#
# Per the result, Civilian labor force for each year goes with the Employed, Unemployed columns for that specific years

# %%
df.corr()
# Out:
#                            FIPS_code  Civilian_labor_force_2017  \
# FIPS_code                   1.000000                  -0.062200
# Civilian_labor_force_2017  -0.062200                   1.000000
# Employed_2017              -0.062318                   0.999961
# Unemployed_2017            -0.058597                   0.982650
# Unemployment_rate_2017      0.185432                  -0.055574
# Civilian_labor_force_2018  -0.062429                   0.999937
# Employed_2018              -0.062533                   0.999882
# Unemployed_2018            -0.058823                   0.982077
# Unemployment_rate_2018      0.152364                  -0.054847
# Civilian_labor_force_2019  -0.062081                   0.999799
# Employed_2019              -0.062186                   0.999736
# Unemployed_2019            -0.058070                   0.978656
# Unemployment_rate_2019      0.154293                  -0.066258
# Civilian_labor_force_2020  -0.051507                   0.999366
# ...

# %% [markdown]
# ## 4. Inference:

# %% [markdown]
# ##### 1. Find which County has highest employment rate per year.

# %%
#calculate the highest employment rate for each year, use the max function and
#Print the result

HighERperCounty = df[['Employment_rate_2017','Employment_rate_2018','Employment_rate_2019','Employment_rate_2020','Employment_rate_2021']].max()
HighERperCounty
# Out:
# Employment_rate_2017    98.5
# Employment_rate_2018    98.8
# Employment_rate_2019    99.2
# Employment_rate_2020    98.5
# Employment_rate_2021    99.1
# dtype: float64

# %%
#The index for highest employment rate for each year can be returned using idxmax function

#Get the County name for those index


y = df[['Employment_rate_2017','Employment_rate_2018','Employment_rate_2019','Employment_rate_2020','Employment_rate_2021']].idxmax()

countyName = df['Area_name'][y]
countyName
# Out:
# 253         Baca County, CO
# 2005      Divide County, ND
# 2677      Loving County, TX
# 929     Hamilton County, KS
# 2661        King County, TX
# Name: Area_name, dtype: object

# %% [markdown]
# Per the result, "Loving county" from Texas holds the highest employment rate which is 99.2 for the year 2019

# %% [markdown]
# ###### 2. Find the percentage of 2021 Employment rate which are between 80 and 90.

# %%
a = df.Employment_rate_2019[(df['Employment_rate_2021']>80) & (df['Employment_rate_2021']<90)].count()

# Now, we will calculate the overall number of all values present in 'Employment_rate_2019' column to successfully create the proportion:

b = df.Employment_rate_2019.shape[0]

# once we are done with finding a and b we will divide them and multiply by 100 to get our percentage:

r = (a/b*100)

print('The percentage of Employment_rate_2021 which are between 80 and 90 is:\n',r)
# Out:
# The percentage of Employment_rate_2021 which are between 80 and 90 is:
#  1.8610421836228286

# %% [markdown]
# ###### 3. Show year-wise labor force trend. Make statement about the trend you get

# %%
#Calculate the labor force for year using sum function

#Divide the result by 1 million to make it easy to read figure and print the result

Labor_force = df[['Civilian_labor_force_2017','Civilian_labor_force_2018','Civilian_labor_force_2019','Civilian_labor_force_2020','Civilian_labor_force_2021']].sum(axis = 0,numeric_only = True)
print("The Labor force(in million) across USA for each year is :")
print(Labor_force/1000000)
# Out:
# The Labor force(in million) across USA for each year is :
# Civilian_labor_force_2017    161.841391
# Civilian_labor_force_2018    163.121411
# Civilian_labor_force_2019    164.907007
# Civilian_labor_force_2020    161.207341
# Civilian_labor_force_2021    162.930710
# dtype: float64

# %%
#Define a new figure and specify that only a single subplot will be placed within the figure
#Plot the figure with green dashed line and marker o
#Provide the labels and plot the graph


fig = plt.figure()
linplt = fig.add_subplot(1, 1, 1)
linplt.plot(Labor_force, color='g', linestyle='dashed',marker ='o' )
labels = linplt.set_xticklabels(['2017','2018','2019','2020','2021'],rotation = 45, fontsize='small')
# Out:
# /var/folders/8c/bpq0ppgn4zg2ytr7qf50_h5w0000gn/T/ipykernel_43864/11419103.py:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   labels = linplt.set_xticklabels(['2017','2018','2019','2020','2021'],rotation = 45, fontsize='small')

# %% [markdown]
# With 164.9 million people working, the labor force peaked in 2019 and declined to 161.2 million people in 2020.

# %% [markdown]
# ###### now we will Plot the line graph using seaborn and set the labels for same graph.

# %%
sns.lineplot(data = Labor_force,marker = 'o').set_xticklabels(['2017','2018','2019','2020','2021'],rotation = 45)
# Out:
# /var/folders/8c/bpq0ppgn4zg2ytr7qf50_h5w0000gn/T/ipykernel_43864/1948672946.py:1: UserWarning: FixedFormatter should only be used together with FixedLocator
#   sns.lineplot(data = Labor_force,marker = 'o').set_xticklabels(['2017','2018','2019','2020','2021'],rotation = 45)
# [Text(0, 0, '2017'),
#  Text(1, 0, '2018'),
#  Text(2, 0, '2019'),
#  Text(3, 0, '2020'),
#  Text(4, 0, '2021')]

# %% [markdown]
# ###### 4. From total labor force, what is the proportion of the 5 states with lowest/highest employment rates?

# %%
#Check the total labor force state-wise
#using groupby function.

Labor_force=df.groupby(df['State'])[['Civilian_labor_force_2017','Civilian_labor_force_2018','Civilian_labor_force_2019','Civilian_labor_force_2020','Civilian_labor_force_2021']].sum().sum(axis = 1)
Labor_force
# Out:
# State
# AK     1770749.0
# AL    11231163.0
# AR     6754806.0
# AZ    16976051.0
# CA    95738619.0
# CO    15357443.0
# CT     9559264.0
# DC     1960999.0
# DE     2422458.0
# FL    50747060.0
# GA    25648595.0
# HI     3402877.0
# IA     8520434.0
# ID     4406288.0
# IL    32385001.0
# IN    16757576.0
# KS     7463299.0
# KY    10232519.0
# LA    10454096.0
# MA    18858896.0
# MD    16234542.0
# ME     3465761.0
# MI    24443024.0
# MN    15430840.0
# MO    15271124.0
# MS     6316043.0
# MT     2697214.0
# NC    24590291.0
# ND     2061452.0
# NE     5199805.0
# NH     3817417.0
# NJ    23215471.0
# NM     4741828.0
# NV     7486483.0
# NY    48577153.0
# OH    28976869.0
# OK     9189625.0
# OR    10503767.0
# PA    32435147.0
# PR     4441227.0
# RI     2849768.0
# SC    11557639.0
# SD     2303931.0
# TN    16424857.0
# TX    69121192.0
# UT     8078041.0
# VA    21829949.0
# VT     1737139.0
# WA    19317777.0
# WI    15632086.0
# WV     3947101.0
# WY     1465104.0
# ...

# %%
Labor_force = Labor_force.sort_values()
Labor_force
# Out:
# State
# WY     1465104.0
# VT     1737139.0
# AK     1770749.0
# DC     1960999.0
# ND     2061452.0
# SD     2303931.0
# DE     2422458.0
# MT     2697214.0
# RI     2849768.0
# HI     3402877.0
# ME     3465761.0
# NH     3817417.0
# WV     3947101.0
# ID     4406288.0
# PR     4441227.0
# NM     4741828.0
# NE     5199805.0
# MS     6316043.0
# AR     6754806.0
# KS     7463299.0
# NV     7486483.0
# UT     8078041.0
# IA     8520434.0
# OK     9189625.0
# CT     9559264.0
# KY    10232519.0
# LA    10454096.0
# OR    10503767.0
# AL    11231163.0
# SC    11557639.0
# MO    15271124.0
# CO    15357443.0
# MN    15430840.0
# WI    15632086.0
# MD    16234542.0
# TN    16424857.0
# IN    16757576.0
# AZ    16976051.0
# MA    18858896.0
# WA    19317777.0
# VA    21829949.0
# NJ    23215471.0
# MI    24443024.0
# NC    24590291.0
# GA    25648595.0
# OH    28976869.0
# IL    32385001.0
# PA    32435147.0
# NY    48577153.0
# FL    50747060.0
# TX    69121192.0
# CA    95738619.0
# ...

# %% [markdown]
# Data were sorted to get the greatest and lowest values, and they were then saved to the same variable.
#
# California has the greatest work force, while Wyoming has the lowest.

# %%
#To get the 5 states with lowest labor force give index 0:5 and print the result
#Calculate the percentage of these by dividing it from the total labor force

Labor_force[0:5]
print(Labor_force[0:5])

LowER = (Labor_force[0:5].sum())*100/Labor_force.sum()
print(round((LowER),2))
# Out:
# State
# WY    1465104.0
# VT    1737139.0
# AK    1770749.0
# DC    1960999.0
# ND    2061452.0
# dtype: float64
# 1.11

# %% [markdown]
# "Wyoming", "Vermont", "Alaska", "Washington DC" and "Nevada" have the 5 lowest labor force
#
# These 5 states holds only '1.11' of the total USA labor force.

# %%
#To get the 5 states with higest labor force 
#Calculate the percentage of these by dividing it from the total labor force

Labor_force[-5:]
print(Labor_force[-5:])

HighER = (Labor_force[-5:].sum())*100/Labor_force.sum()
print(round((HighER),2))
# Out:
# State
# PA    32435147.0
# NY    48577153.0
# FL    50747060.0
# TX    69121192.0
# CA    95738619.0
# dtype: float64
# 36.44

# %% [markdown]
# California, Texas, Florida, New York and Pennsylvania holds for 5 highest labor force
#
# These 5 states holds 36.44 of the total USA labor force

# %% [markdown]
# ###### 5. Compare unemployment rate before and after pandemic?

# %%
#Calculating average unemployment rate for all states from 2017-2019 to get pre pandemic umployment rate

pre_pan = df[['Unemployment_rate_2019','Unemployment_rate_2020','Unemployment_rate_2021']].mean()
pre_pan
# Out:
# Unemployment_rate_2019    4.097950
# Unemployment_rate_2020    6.748695
# Unemployment_rate_2021    4.766739
# dtype: float64

# %%
plt.rcParams["figure.figsize"] = [6, 6]
pre_pan.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# According to our graph, the number of jobless peaked in 2020. The unemployment rate was 4.09 before Covid, and it was 4.76 after Covid.

# %% [markdown]
# #### With the aid of MATPLOTLIB, we now go further and perform some visualizations. Between 2019 and 2021, we'll determine which state has more than 100,000 unemployed.

# %%
n_df = df[(df['total_unemployed'] >= 100000)]
n_df
# Out:
#       FIPS_code State                Area_name  Civilian_labor_force_2017  \
# 108        4013    AZ      Maricopa County, AZ                  2088547.0
# 111        4019    AZ          Pima County, AZ                   464230.0
# 191        6001    CA       Alameda County, CA                   838175.0
# 197        6013    CA  Contra Costa County, CA                   557869.0
# 200        6019    CA        Fresno County, CA                   444452.0
# ...         ...   ...                      ...                        ...
# 2852      51059    VA       Fairfax County, VA                   629074.0
# 2973      53033    WA          King County, WA                  1231166.0
# 2983      53053    WA        Pierce County, WA                   417889.0
# 2987      53061    WA     Snohomish County, WA                   421436.0
# 3091      55079    WI     Milwaukee County, WI                   476413.0
#
#       Employed_2017  Unemployed_2017  Unemployment_rate_2017  \
# ...

# %%
df1 = pd.DataFrame(n_df, columns=["Area_name","Unemployed_2019", "Unemployed_2020", "Unemployed_2021"])
 
# plot the dataframe
df1.plot(x="Area_name", y=["Unemployed_2019","Unemployed_2020", "Unemployed_2021"], kind="bar", figsize=(18, 8))
 
# print bar graph
plt.show()

# %% [markdown]
# We can observe that the following summary is quite interesting:
#
# In 2019 unemployed people were below 100,000 in every states except Cook,IL.
#
# In 2020 the highest unemployed crossed more than 600,000 due to Covid.
#
# In 2021 the unemployment numbers looks comparatively lower crossing 400,000 but it is still very high when compared to 2019's unemployment numbers.

# %% [markdown]
# Now we will use Python's seaborn library because we want a more colorful, and a meaningful graph whichcan help us to draw a conclusion in a much nicer and detailed way:

# %%
sns.barplot(x ='State', y ='total_unemployed', data = n_df,  
            palette ='plasma')
# Out:
# <AxesSubplot:xlabel='State', ylabel='total_unemployed'>

# %% [markdown]
# Per the above graph, in the states of AZ, CA, IL, and NV, the average number of jobless persons was more than 300,000.

# %% [markdown]
# ###### 6. State-wise unemployment rate for all the years

# %%
#finding the highest umemployment rate

max_unemp=round(df['unemp_rate'].max(),2)
max_unemp
# Out:
# 0.2

# %%
m_unemp = df.groupby(['State',]).agg({'unemp_rate':'max'})

m_unemp
# Out:
#        unemp_rate
# State
# AK       0.189636
# AL       0.112099
# AR       0.077759
# AZ       0.161602
# CA       0.199340
# CO       0.068527
# CT       0.054908
# DC       0.063169
# DE       0.055624
# FL       0.069774
# GA       0.092812
# HI       0.063855
# IA       0.053037
# ID       0.071252
# IL       0.085795
# IN       0.062463
# KS       0.057649
# KY       0.133830
# LA       0.108014
# MA       0.065407
# MD       0.085333
# ME       0.051881
# MI       0.102577
# MN       0.084416
# MO       0.071850
# MS       0.157113
# MT       0.092666
# NC       0.085295
# ND       0.101077
# NE       0.048035
# NH       0.044906
# NJ       0.092791
# NM       0.137516
# NV       0.075709
# NY       0.092946
# OH       0.085239
# OK       0.072712
# OR       0.070870
# PA       0.079368
# PR       0.159774
# RI       0.058158
# SC       0.070723
# SD       0.093234
# TN       0.064178
# TX       0.131691
# UT       0.074928
# VA       0.086964
# VT       0.051925
# ...

# %% [markdown]
# Here is the highest unemployment rate by state.

# %%
m_unemp.max() # find highest rate of unemployement all above states.
# Out:
# unemp_rate    0.19934
# dtype: float64

# %% [markdown]
# The highest rate of unemployement all above the states is 0.19934.

# %% [markdown]
# ###### 7. Compare among NY, NJ & CT - Employment rate and Unemployment.

# %%
#using pivot table to find employment rate
tristate_emp=df.query('State == ["NY", "NJ", "CT"]').pivot_table(
        columns=['State'],
        values='emp_rate',
        aggfunc='mean',
    fill_value=0)
tristate_emp
# Out:
# State           CT        NJ        NY
# emp_rate  0.950167  0.942193  0.946104

# %% [markdown]
# We have compared employment rate for NY, NJ & CT
#
# NY & CT has almost same employment rate of 95%. NJ employment rate is slightly less, 94%.

# %% [markdown]
# ###### Now we will use Matplotlib Plot for NY, NJ & CT employment rate comparison:

# %%
#plt.rcParams["figure.figsize"] = [10, 6]
tristate_emp.plot.bar(grid=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Graph shows that NJ had the low employment rate as compare to CT and ny.

# %%
#using pivot table to find unemployment rate

#Using query() function to filter states

tstate_unemp=df.query('State == ["NY", "NJ", "CT"]').pivot_table(
        columns=['State'],
        values='unemp_rate',
        #index=['County'],
        aggfunc='mean',
    fill_value=0)
tstate_unemp
# Out:
# State             CT        NJ        NY
# unemp_rate  0.049833  0.057807  0.053896

# %% [markdown]
# we can see NY & CT has almost same unemployment rate of 5%. NJ employment rate is slightly higher 6%.

# %%
tstate_unemp.plot.bar(grid=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Graph shows that NJ had the highest unemployment rate.

# %% [markdown]
# Now we will use seaborn for NY, NJ & CT employment rate comparison:

# %%
t = df.query('State == ["NY", "NJ", "CT"]')

# %%
#compare NY, NJ & CT employment rate:

x = sns.stripplot(x='State', y='total_employed', data=t)

  
# giving title to the plot
plt.title('Using Seaborn:NY, NJ & CT employment rate comparison:')
  
# function to show plot
plt.show()

# %%
#compare NY, NJ & CT unemployment rate:

x = sns.swarmplot(x='State', y='total_unemployed', data=t)
  
# giving title to the plot
plt.title('Using Seaborn(swarmplot):NY, NJ & CT unemployment rate comparison:')
  
# function to show plot
plt.show()
# Out:
# /Users/aishu/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 17.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# We can see that NY has most Unemployed number

# %% [markdown]
# We can also draw this plot with matplotlib but the problem with matplotlib is its default parameters. The reason why Seaborn is so great with DataFrames is, for example, labels from DataFrames are automatically propagated to plots or other data structures as you see in the above figure column 'State' comes on the x-axis and column name 'total_unemployed' comes on the y-axis, that is not possible with matplotlib. We have to explicitly define the labels of the x-axis and y-axis.

# %% [markdown]
# ###### 8. Find which NY county impacted the most after Covid.

# %%
n_e=t.query('Unemployed_2021 >100000') # we are taking greater than 100000 unemployed values.

# %%
sns.catplot(x="State", y="Unemployed_2021", data=n_e, kind="strip",hue="Area_name", jitter=False, dodge=True)

# %% [markdown]
# we can see from above graph that Kings county was impacted most

# %%
jp = sns.jointplot("Unemployed_2020", "Unemployed_2021", data=t)
# Out:
# /Users/aishu/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# From the above graph we can relatively see the unemployement in 2020 and 2021, and there are highest unemployement in 2020.

# %% [markdown]
# ## 5. CONCLUSION:
#
# 1. Loving county from Texas holds the highest employment rate which is 99.2 for the year 2019
#
# 2. With 164.9 million people working, the labor force peaked in 2019 and declined to 161.2 million people in 2020.
#
# 3. California has the greatest work force, while Wyoming has the lowest.
#
# 4. "Wyoming", "Vermont", "Alaska", "Washington DC" and "Nevada" have the 5 lowest labor force. These 5 states holds only '1.11' of the total USA labor force.
#
# 5. California, Texas, Florida, New York and Pennsylvania holds for 5 highest labor force. These 5 states holds '36.44' of the total USA labor force
#
# 6. The number of unemployment peaked in 2020. The unemployment rate was 4.09 before Covid, and it was 4.76 after Covid.
#
# 7. In 2019 unemployed people were below 100,000 in every states except Cook,IL. In 2020 the highest unemployed crossed more than 600,000 due to Covid. In 2021 the unemployment numbers looks comparatively lower crossing 400,000 but it is still very high when compared to 2019's unemployment numbers.
#
# 8. NY & CT has almost same employment rate of 95%. NJ employment rate is slightly less, 94%.
#
# 9. The maximum unemployement rate is 0.19934 and it is for CA state
#
# The highest impacted states are AZ, IL, CA, NY, and NV, so we conclude that these states need government help and subsidies to overcome this situation.
#
# It would be great initiative if government takes part in increasing the state budget that is assigned to social services and public infrastructure in deprived regions. Long-term unemployed persons are more likely to contribute to social instability. Government should initiate plans to raise people's standard of living.

# %% [markdown]
# ## REFERENCES:

# %% [markdown]
# https://catalog.data.gov/dataset/local-area-unemployment-statistics-47d02
#
# https://fred.stlouisfed.org/tags/series?t=monthly%3Bunemployment%3Busa
#
# https://www.bls.gov/covid19/effects-of-covid-19-pandemic-on-employment-and-unemployment-statistics.htm
